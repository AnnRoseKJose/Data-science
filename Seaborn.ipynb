# %%
import seaborn as sns
import pandas as pd
df=pd.read_csv("Dataset_w6.csv")
df
# Out:
#                  country          Region  Surface area (km2)  \
# 0            Afghanistan    SouthernAsia            652864.0
# 1                Albania  SouthernEurope             28748.0
# 2                Algeria  NorthernAfrica           2381741.0
# 3                 Angola    MiddleAfrica           1246700.0
# 4    Antigua and Barbuda       Caribbean               442.0
# ..                   ...             ...                 ...
# 994                  NaN             NaN                 NaN
# 995                  NaN             NaN                 NaN
# 996                  NaN             NaN                 NaN
# 997                  NaN             NaN                 NaN
# 998                  NaN             NaN                 NaN
#
#      Population in thousands (2017)  GDP per capita (current US$)  \
# 0                           35530.0                         623.2
# 1                            2930.0                        3984.2
# ...

# %% [markdown]
# # 1) Distribution plot

# %%
sns.distplot(df['Surface area (km2)'],kde=False, bins=25)
# Out:
# C:\Users\JOS\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Surface area (km2)'>

# %% [markdown]
# # 2) Joint plot

# %%
sns.jointplot(x='Population in thousands (2017)',y='International trade: Imports (million US$)',data=df,kind='reg')
 #kind=kde,hex

# %% [markdown]
# # 3) KDE Plot

# %%
sns.kdeplot(df['GDP per capita (current US$)'])
# Out:
# <AxesSubplot:xlabel='GDP per capita (current US$)', ylabel='Density'>

# %% [markdown]
# # 4) Pair plot

# %%
sns.pairplot(df)

# %%
SA_df = sns.load_dataset('Surface area (km2)')
sns.pairplot(SA_df, hue='Region', palette='Blues')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8688\1810245311.py in <module>
# ----> 1 SA_df = sns.load_dataset('Surface area (km2)')
#       2 sns.pairplot(SA_df, hue='Region', palette='Blues')
#
# ~\anaconda3\lib\site-packages\seaborn\utils.py in load_dataset(name, cache, data_home, **kws)
#     593         if not os.path.exists(cache_path):
#     594             if name not in get_dataset_names():
# --> 595                 raise ValueError(f"'{name}' is not one of the example datasets.")
#     596             urlretrieve(url, cache_path)
#     597         full_path = cache_path
#
# ValueError: 'Surface area (km2)' is not one of the example datasets.

# %%
sns.rugplot(df['Region'])
# Out:
# <AxesSubplot:xlabel='Region'>

# %%
df
# Out:
#      Surface area (km2)  Population in thousands (2017)  \
# 0              652864.0                         35530.0
# 1               28748.0                          2930.0
# 2             2381741.0                         41318.0
# 3             1246700.0                         29784.0
# 4                 442.0                           102.0
# ..                  ...                             ...
# 994                 NaN                             NaN
# 995                 NaN                             NaN
# 996                 NaN                             NaN
# 997                 NaN                             NaN
# 998                 NaN                             NaN
#
#      GDP per capita (current US$)  Agricultural production index   \
# 0                           623.2                           125.0
# 1                          3984.2                           134.0
# 2                          4154.1                           160.0
# ...

# %%
a=df.dropna()
a
# Out:
#      Surface area (km2)  Population in thousands (2017)  \
# 0              652864.0                         35530.0
# 1               28748.0                          2930.0
# 2             2381741.0                         41318.0
# 3             1246700.0                         29784.0
# 4                 442.0                           102.0
# ..                  ...                             ...
# 191            912050.0                         31977.0
# 192            330967.0                         95541.0
# 193            527968.0                         28250.0
# 194            752612.0                         17094.0
# 195            390757.0                         16530.0
#
#      GDP per capita (current US$)  Agricultural production index   \
# 0                           623.2                           125.0
# 1                          3984.2                           134.0
# 2                          4154.1                           160.0
# ...

# %%
sns.heatmap(a.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.isna().sum() #gets no of na
# Out:
# Surface area (km2)                            803
# Population in thousands (2017)                803
# GDP per capita (current US$)                  803
# Agricultural production index                 803
# International trade: Imports (million US$)    803
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 5 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Surface area (km2)                          196 non-null    float64
#  1   Population in thousands (2017)              196 non-null    float64
#  2   GDP per capita (current US$)                196 non-null    float64
#  3   Agricultural production index               196 non-null    float64
#  4   International trade: Imports (million US$)  196 non-null    float64
# dtypes: float64(5)
# memory usage: 39.1 KB

# %%
df['Surface area (km2)'].isna().sum()
# Out:
# 803

# %%
df['Surface area (km2)'].isna().sum()
# Out:
# 803

# %%
df.fillna(5) #fill NA with 5s
# Out:
#      Surface area (km2)  Population in thousands (2017)  \
# 0              652864.0                         35530.0
# 1               28748.0                          2930.0
# 2             2381741.0                         41318.0
# 3             1246700.0                         29784.0
# 4                 442.0                           102.0
# ..                  ...                             ...
# 994                 5.0                             5.0
# 995                 5.0                             5.0
# 996                 5.0                             5.0
# 997                 5.0                             5.0
# 998                 5.0                             5.0
#
#      GDP per capita (current US$)  Agricultural production index   \
# 0                           623.2                           125.0
# 1                          3984.2                           134.0
# 2                          4154.1                           160.0
# ...

# %%
df.fillna(method='ffill') #fill NA with just prev. value
# Out:
#      Surface area (km2)  Population in thousands (2017)  \
# 0              652864.0                         35530.0
# 1               28748.0                          2930.0
# 2             2381741.0                         41318.0
# 3             1246700.0                         29784.0
# 4                 442.0                           102.0
# ..                  ...                             ...
# 994            390757.0                         16530.0
# 995            390757.0                         16530.0
# 996            390757.0                         16530.0
# 997            390757.0                         16530.0
# 998            390757.0                         16530.0
#
#      GDP per capita (current US$)  Agricultural production index   \
# 0                           623.2                           125.0
# 1                          3984.2                           134.0
# 2                          4154.1                           160.0
# ...

# %%
df.fillna(method='bfill') #fill NA with just forwd. value
# Out:
#      Surface area (km2)  Population in thousands (2017)  \
# 0              652864.0                         35530.0
# 1               28748.0                          2930.0
# 2             2381741.0                         41318.0
# 3             1246700.0                         29784.0
# 4                 442.0                           102.0
# ..                  ...                             ...
# 994                 NaN                             NaN
# 995                 NaN                             NaN
# 996                 NaN                             NaN
# 997                 NaN                             NaN
# 998                 NaN                             NaN
#
#      GDP per capita (current US$)  Agricultural production index   \
# 0                           623.2                           125.0
# 1                          3984.2                           134.0
# 2                          4154.1                           160.0
# ...

# %%
values = {"Surface area (km2)": 100, "Population in thousands (2017)": 200, "GDP per capita (current US$)": 300, "Agricultural production index": 400}
df.fillna(value=values)
# Out:
#      Surface area (km2)  Population in thousands (2017)  \
# 0              652864.0                         35530.0
# 1               28748.0                          2930.0
# 2             2381741.0                         41318.0
# 3             1246700.0                         29784.0
# 4                 442.0                           102.0
# ..                  ...                             ...
# 994               100.0                           200.0
# 995               100.0                           200.0
# 996               100.0                           200.0
# 997               100.0                           200.0
# 998               100.0                           200.0
#
#      GDP per capita (current US$)  Agricultural production index   \
# 0                           623.2                           125.0
# 1                          3984.2                           134.0
# 2                          4154.1                           160.0
# ...

# %%
list('ABCDE')
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
import numpy as np

# %%
a=np.random.randint(50,size=(4,4))
a
# Out:
# array([[11, 49, 43,  8],
#        [ 3, 11,  8, 39],
#        [34, 32, 25, 20],
#        [41, 37, 43, 26]])

# %%
df2 = pd.DataFrame(a, columns=list("ABCE"))
df2
# Out:
#     A   B   C   E
# 0  11  49  43   8
# 1   3  11   8  39
# 2  34  32  25  20
# 3  41  37  43  26

# %%
df1 = pd.DataFrame([[np.nan, 2, np.nan, 0],
                   [3, 4, np.nan, 1],
                   [np.nan, np.nan, np.nan, np.nan],
                   [np.nan, 3, np.nan, 4]],
                  columns=list("ABCD"))
df1
# Out:
#      A    B   C    D
# 0  NaN  2.0 NaN  0.0
# 1  3.0  4.0 NaN  1.0
# 2  NaN  NaN NaN  NaN
# 3  NaN  3.0 NaN  4.0

# %%
df1.fillna(df2)
# Out:
#       A     B     C    D
# 0  11.0   2.0  43.0  0.0
# 1   3.0   4.0   8.0  1.0
# 2  34.0  32.0  25.0  NaN
# 3  41.0   3.0  43.0  4.0
