# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("Dataset_w6.csv")
df
# Out:
#                  country          Region  Surface area (km2)  \
# 0            Afghanistan    SouthernAsia            652864.0
# 1                Albania  SouthernEurope             28748.0
# 2                Algeria  NorthernAfrica           2381741.0
# 3                 Angola    MiddleAfrica           1246700.0
# 4    Antigua and Barbuda       Caribbean               442.0
# ..                   ...             ...                 ...
# 994                  NaN             NaN                 NaN
# 995                  NaN             NaN                 NaN
# 996                  NaN             NaN                 NaN
# 997                  NaN             NaN                 NaN
# 998                  NaN             NaN                 NaN
#
#      Population in thousands (2017)  GDP per capita (current US$)  \
# 0                           35530.0                         623.2
# 1                            2930.0                        3984.2
# ...

# %% [markdown]
# # a) Find out the number of countries in each Region

# %%
a=df.groupby('Region')[['country']].count()
a
# Out:
#                    country
# Region
# Caribbean               16
# CentralAmerica           8
# CentralAsia              5
# EasternAfrica           17
# EasternAsia              7
# EasternEurope           10
# Melanesia                5
# Micronesia               4
# MiddleAfrica             9
# NorthernAfrica           5
# NorthernAmerica          4
# NorthernEurope          10
# Oceania                  2
# Polynesia                5
# South-easternAsia       11
# SouthAmerica            12
# SouthernAfrica           5
# SouthernAsia             9
# SouthernEurope          12
# WesternAfrica           15
# WesternAsia             18
# WesternEurope            7

# %%
a.reset_index(inplace=True)
a
# Out:
#                Region  country
# 0           Caribbean       16
# 1      CentralAmerica        8
# 2         CentralAsia        5
# 3       EasternAfrica       17
# 4         EasternAsia        7
# 5       EasternEurope       10
# 6           Melanesia        5
# 7          Micronesia        4
# 8        MiddleAfrica        9
# 9      NorthernAfrica        5
# 10    NorthernAmerica        4
# 11     NorthernEurope       10
# 12            Oceania        2
# 13          Polynesia        5
# 14  South-easternAsia       11
# 15       SouthAmerica       12
# 16     SouthernAfrica        5
# 17       SouthernAsia        9
# 18     SouthernEurope       12
# 19      WesternAfrica       15
# 20        WesternAsia       18
# 21      WesternEurope        7

# %%
plt.bar(a['Region'],a['country'])
plt.xticks(a['Region'],rotation='vertical')
plt.show()

# %% [markdown]
# # b) Plot a graph showing interational trade with respect to paopulation

# %%
plt.scatter(df['Population in thousands (2017)'],df['International trade: Imports (million US$)'])
plt.xlabel('Population in thousands (2017)')
plt.ylabel('International trade: Imports (million US$)')
plt.xlim(0,50000)
plt.ylim(0,50000)
plt.show()

# %% [markdown]
# # c) plot a graph showing how GDP_per_capita affects agricultural production index

# %%
df.columns
# Out:
# Index(['country', 'Region', 'Surface area (km2)',
#        'Population in thousands (2017)', 'GDP per capita (current US$)',
#        'Agricultural production index ',
#        'International trade: Imports (million US$)'],
#       dtype='object')

# %%
df['Agricultural production index ']
# Out:
# 0      125.0
# 1      134.0
# 2      160.0
# 3      175.0
# 4       88.0
#        ...
# 994      NaN
# 995      NaN
# 996      NaN
# 997      NaN
# 998      NaN
# Name: Agricultural production index , Length: 999, dtype: float64

# %%
plt.scatter(df['GDP per capita (current US$)'],df['Agricultural production index '])
plt.xlabel('GDP per capita (current US$)')
plt.ylabel('Agricultural production index')
#plt.xlim(0,50000)
plt.ylim(0,200)
plt.show()

# %% [markdown]
# # d) plot a graph showing which region has highest GDP per capital

# %%
d=df.groupby('Region')[['GDP per capita (current US$)']].max()
d.reset_index(inplace=True)
d
# Out:
#                Region  GDP per capita (current US$)
# 0           Caribbean                       62132.0
# 1      CentralAmerica                       13268.1
# 2         CentralAsia                       10312.1
# 3       EasternAfrica                       14133.2
# 4         EasternAsia                       78586.4
# 5       EasternEurope                       17561.7
# 6           Melanesia                       33965.7
# 7          Micronesia                       12122.5
# 8        MiddleAfrica                       16344.1
# 9      NorthernAfrica                        5488.2
# 10    NorthernAmerica                       94399.9
# 11     NorthernEurope                       74185.5
# 12            Oceania                       51352.2
# 13          Polynesia                       18161.0
# 14  South-easternAsia                       52239.0
# 15       SouthAmerica                       15573.8
# 16     SouthernAfrica                        6360.6
# ...

# %%
plt.bar(d['Region'],d['GDP per capita (current US$)'])
plt.xticks(d['Region'],rotation='vertical')
plt.grid(visible=True)
plt.xlabel('Region')
plt.ylabel('GDP per capita (current US$)')
plt.show()

# %% [markdown]
# # e) Plot a graph and show which region has highest interational trade imports

# %%
e=df.groupby('Region')[['International trade: Imports (million US$)']].max()
e.reset_index(inplace=True)
e
# Out:
#                Region  International trade: Imports (million US$)
# 0           Caribbean                                     22725.0
# 1      CentralAmerica                                    387064.0
# 2         CentralAsia                                     25652.0
# 3       EasternAfrica                                     19121.0
# 4         EasternAsia                                   1588696.0
# 5       EasternEurope                                    188518.0
# 6           Melanesia                                      8874.0
# 7          Micronesia                                       154.0
# 8        MiddleAfrica                                      9793.0
# 9      NorthernAfrica                                     58053.0
# 10    NorthernAmerica                                   2249661.0
# 11     NorthernEurope                                    635570.0
# 12            Oceania                                    189406.0
# ...

# %%
plt.bar(e['Region'],e['International trade: Imports (million US$)'])
plt.xticks(e['Region'],rotation='vertical')
plt.xlabel('Region')
plt.ylabel('International trade: Imports (million US$)')
plt.ylim(100,2300000.0)
plt.show()

# %% [markdown]
# # f) plot a graph to show which region is more consitent to GDP

# %%
plt.scatter(df['Region'],df['GDP per capita (current US$)'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6452\3342559116.py in <module>
# ----> 1 plt.scatter(df['Region'],df['GDP per capita (current US$)'])
#       2 plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2817         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2818         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2819     __ret = gca().scatter(
#    2820         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2821         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
# ...
