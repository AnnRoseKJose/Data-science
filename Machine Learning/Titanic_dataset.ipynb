# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("titanic_dataset.csv")
pd.pandas.set_option('display.max_columns',None)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # 1) Make passengerId as index column

# %%
a = df.set_index("PassengerId")
a
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# # 2) Check the basic details of the dataset

# %%
df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # 3) Fill in all the missing values present in all the columns in the dataset

# %%
b = df.isna().sum()
b
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
c = df.dropna()
c
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
d = df.fillna("None") #fill NaN with none
d
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# To fill on one column
e = df["Cabin"].fillna("NoCabin")
df1 = pd.DataFrame(e)
df1
# Out:
#        Cabin
# 0    NoCabin
# 1        C85
# 2    NoCabin
# 3       C123
# 4    NoCabin
# ..       ...
# 886  NoCabin
# 887      B42
# 888  NoCabin
# 889     C148
# 890  NoCabin
#
# [891 rows x 1 columns]

# %%
# fillna() on multiple columns
e =  df.fillna(value={'Age':'not given','Cabin':'NoCabin','Embarked':0})
e
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male       22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female       38.0
# 2                               Heikkinen, Miss. Laina  female       26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female       35.0
# 4                             Allen, Mr. William Henry    male       35.0
# ..                                                 ...     ...        ...
# ...

# %%
a=df['Cabin'].mode()[0]
b=a.split(' ')
c=b[0]

# %%
df['Age'].mode()
# Out:
# 0    24.0
# Name: Age, dtype: float64

# %%
# Fill data with mean
fill_data=['Age','Cabin','Embarked']
for i in fill_data:
    if df[i].dtype=='O':
        a=df[i].mode()[0]
        b=a.split(' ') 
        c=b[0]
        df[i].fillna(c,inplace=True)
    else:
        df[i].fillna(df[i].mean(),inplace=True)
    print(i)
df
# Out:
# Age
# Cabin
# Embarked
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ...

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# # DATA PREPROCESSING

# %% [markdown]
# 1. To sort out Numerical features

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
features = ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
       'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']
numerical_features=[]
for feature in features:
    if df[feature].dtypes!='O':
        numerical_features.append(feature)
print(numerical_features)
print('Length of numerical features = ',len(numerical_features))
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']
# Length of numerical features =  7

# %% [markdown]
# 2. To find out Discrete features

# %%
discrete_features=[]
for feature in features:
    if len(df[feature].unique())<10:
        discrete_features.append(feature)
discrete_features
# Out:
# ['Survived', 'Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked']

# %%
df[discrete_features]
# Out:
#      Survived  Pclass     Sex  SibSp  Parch Embarked
# 0           0       3    male      1      0        S
# 1           1       1  female      1      0        C
# 2           1       3  female      0      0        S
# 3           1       1  female      1      0        S
# 4           0       3    male      0      0        S
# ..        ...     ...     ...    ...    ...      ...
# 886         0       2    male      0      0        S
# 887         1       1  female      0      0        S
# 888         0       3  female      1      2        S
# 889         1       1    male      0      0        C
# 890         0       3    male      0      0        Q
#
# [891 rows x 6 columns]

# %% [markdown]
# 3. To find out continuous features

# %%
continuous_features =[]
for feature in features:
    if feature not in discrete_features:
        continuous_features.append(feature)
continuous_features
# Out:
# ['PassengerId', 'Name', 'Age', 'Ticket', 'Fare', 'Cabin']

# %%
df[continuous_features]
# Out:
#      PassengerId                                               Name  \
# 0              1                            Braund, Mr. Owen Harris
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3                             Heikkinen, Miss. Laina
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5                           Allen, Mr. William Henry
# ..           ...                                                ...
# 886          887                              Montvila, Rev. Juozas
# 887          888                       Graham, Miss. Margaret Edith
# 888          889           Johnston, Miss. Catherine Helen "Carrie"
# 889          890                              Behr, Mr. Karl Howell
# 890          891                                Dooley, Mr. Patrick
#
#            Age            Ticket     Fare Cabin
# 0    22.000000         A/5 21171   7.2500   B96
# 1    38.000000          PC 17599  71.2833   C85
# ...

# %% [markdown]
# 4.To sort out categorical values

# %%
categorical_features=[]
for feature in features:
    if df[feature].dtypes=='O':
        categorical_features.append(feature)
categorical_features
# Out:
# ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']

# %%
df[categorical_features]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   B96        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   B96        S
# 3              113803  C123        S
# ...

# %% [markdown]
# 5. To plot box plot

# %%
for i in numerical_features:
    df.boxplot(column=i)
    plt.show()

# %% [markdown]
# # 5. To find out outlier values and handle it.

# %%
def IQR_values(df,column_name):
    q1=df[column_name].quantile(0.25) #to set quantille of columns
    q2=df[column_name].quantile(0.50)
    q3=df[column_name].quantile(0.75)
    IQR=q3-q1 #to find IQR value
    low_limit=q1-1.5*IQR #setting low limit and upper limit
    upper_limit=q3+1.5*IQR
    return low_limit,upper_limit

# columns=['age','income','performance_score'] #we r checking outliers of these columns
outlier={}
for column in numerical_features:
    low_limit,upper_limit=IQR_values(df,column)
    outlier[column]=[low_limit,upper_limit]
outlier
# Out:
# {'PassengerId': [-444.0, 1336.0],
#  'Survived': [-1.5, 2.5],
#  'Pclass': [0.5, 4.5],
#  'Age': [2.5, 54.5],
#  'SibSp': [-1.5, 2.5],
#  'Parch': [0.0, 0.0],
#  'Fare': [-26.724, 65.6344]}

# %%
outlier[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_948\95435002.py in <module>
# ----> 1 outlier[0]
#
# KeyError: 0

# %%
# for i in numerical_features:
#     for j in df["Age"].unique():
#             classtype = df[df["Age"] == j]
#             column = classtype[i]
#             q1 = column.quantile(0.25) 
#             q3 = column.quantile(0.75) 
#             iqr = q3 - q1 
#             upper_limit = q3 + 1.5 * iqr
#             lower_limit = q1 - 1.5 * iqr        
#             outliers = column[(column > upper_limit) | (column < lower_limit)].index 
#             df.drop(outliers, inplace=True)
# outliers
# df

# %% [markdown]
# # 6. Replace outliers with mean

# %%
outindx=[]
for i in numerical_features:
    df_outl=(df[i]>outlier[i][1])|(df[i]<outlier[i][0])
    x=df.loc[df_outl].index
    outindx.append(x)
outindx
# Out:
# [Int64Index([], dtype='int64'),
#  Int64Index([], dtype='int64'),
#  Int64Index([], dtype='int64'),
#  Int64Index([], dtype='int64'),
#  Int64Index([], dtype='int64'),
#  Int64Index([  7,   8,  10,  13,  16,  24,  25,  27,  43,  50,
#              ...
#              855, 856, 858, 863, 869, 871, 879, 880, 885, 888],
#             dtype='int64', length=213),
#  Int64Index([], dtype='int64')]

# %%
for i in range(len(numerical_features)):
    df.loc[outindx[i],numerical_features[i]]=df[numerical_features[i]].mean()
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0     3.0
# 1              2       1.0     1.0
# 2              3       1.0     3.0
# 3              4       1.0     1.0
# 4              5       0.0     3.0
# ..           ...       ...     ...
# 886          887       0.0     2.0
# 887          888       1.0     1.0
# 888          889       0.0     3.0
# 889          890       1.0     1.0
# 890          891       0.0     3.0
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
c=df[df["Age"] == 26.0]
c
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3       1.0     3.0
# 69            70       0.0     3.0
# 73            74       0.0     3.0
# 93            94       0.0     3.0
# 162          163       0.0     3.0
# 207          208       1.0     3.0
# 290          291       1.0     1.0
# 312          313       0.0     2.0
# 315          316       1.0     3.0
# 401          402       0.0     3.0
# 509          510       1.0     3.0
# 617          618       0.0     3.0
# 619          620       0.0     2.0
# 628          629       0.0     3.0
# 704          705       0.0     3.0
# 810          811       0.0     3.0
# 870          871       0.0     3.0
# 889          890       1.0     1.0
#
#                                                 Name     Sex   Age  SibSp  \
# 2                             Heikkinen, Miss. Laina  female  26.0    0.0
# 69                                 Kink, Mr. Vincenz    male  26.0    2.0
# ...

# %%
c['Fare']
# Out:
# 2       7.925000
# 69      8.662500
# 73     14.454200
# 93     20.575000
# 162     7.775000
# 207    18.787500
# 290    32.204208
# 312    26.000000
# 315     7.854200
# 401     8.050000
# 509    56.495800
# 617    16.100000
# 619    10.500000
# 628     7.895800
# 704     7.854200
# 810     7.887500
# 870     7.895800
# 889    30.000000
# Name: Fare, dtype: float64

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# # 7. Standard scaling

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()

# %%
df1=df[numerical_features]
df1=df1.drop('PassengerId',axis=1)
df1
# Out:
#      Survived  Pclass        Age  SibSp     Parch       Fare
# 0         0.0     3.0  22.000000    1.0  0.000000   7.250000
# 1         1.0     1.0  38.000000    1.0  0.000000  32.204208
# 2         1.0     3.0  26.000000    0.0  0.000000   7.925000
# 3         1.0     1.0  35.000000    1.0  0.000000  53.100000
# 4         0.0     3.0  35.000000    0.0  0.000000   8.050000
# ..        ...     ...        ...    ...       ...        ...
# 886       0.0     2.0  27.000000    0.0  0.000000  13.000000
# 887       1.0     1.0  19.000000    0.0  0.000000  30.000000
# 888       0.0     3.0  29.699118    1.0  0.091223  23.450000
# 889       1.0     1.0  26.000000    0.0  0.000000  30.000000
# 890       0.0     3.0  32.000000    0.0  0.000000   7.750000
#
# [891 rows x 6 columns]

# %%
x=scalar.fit_transform(df1)
x
# Out:
# array([[-0.78927234,  0.82737724, -0.708584  ,  1.30222249, -0.56049915,
#         -0.91847447],
#        [ 1.2669898 , -1.56610693,  0.92494776,  1.30222249, -0.56049915,
#          0.9232857 ],
#        [ 1.2669898 ,  0.82737724, -0.30020106, -0.62534019, -0.56049915,
#         -0.86865569],
#        ...,
#        [-0.78927234,  0.82737724,  0.07746308,  1.30222249,  1.78412404,
#          0.27717617],
#        [ 1.2669898 , -1.56610693, -0.30020106, -0.62534019, -0.56049915,
#          0.76060282],
#        [-0.78927234,  0.82737724,  0.31237335, -0.62534019, -0.56049915,
#         -0.88157167]])

# %%
df2=pd.DataFrame(x,columns=df1.columns)
df2
# Out:
#      Survived    Pclass       Age     SibSp     Parch      Fare
# 0   -0.789272  0.827377 -0.708584  1.302222 -0.560499 -0.918474
# 1    1.266990 -1.566107  0.924948  1.302222 -0.560499  0.923286
# 2    1.266990  0.827377 -0.300201 -0.625340 -0.560499 -0.868656
# 3    1.266990 -1.566107  0.618661  1.302222 -0.560499  2.465512
# 4   -0.789272  0.827377  0.618661 -0.625340 -0.560499 -0.859430
# ..        ...       ...       ...       ...       ...       ...
# 886 -0.789272 -0.369365 -0.198105 -0.625340 -0.560499 -0.494092
# 887  1.266990 -1.566107 -1.014871 -0.625340 -0.560499  0.760603
# 888 -0.789272  0.827377  0.077463  1.302222  1.784124  0.277176
# 889  1.266990 -1.566107 -0.300201 -0.625340 -0.560499  0.760603
# 890 -0.789272  0.827377  0.312373 -0.625340 -0.560499 -0.881572
#
# [891 rows x 6 columns]

# %%
df.update(df2)
df
# Out:
#      PassengerId  Survived    Pclass  \
# 0              1 -0.789272  0.827377
# 1              2  1.266990 -1.566107
# 2              3  1.266990  0.827377
# 3              4  1.266990 -1.566107
# 4              5 -0.789272  0.827377
# ..           ...       ...       ...
# 886          887 -0.789272 -0.369365
# 887          888  1.266990 -1.566107
# 888          889 -0.789272  0.827377
# 889          890  1.266990 -1.566107
# 890          891 -0.789272  0.827377
#
#                                                   Name     Sex       Age  \
# 0                              Braund, Mr. Owen Harris    male -0.708584
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  0.924948
# 2                               Heikkinen, Miss. Laina  female -0.300201
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  0.618661
# 4                             Allen, Mr. William Henry    male  0.618661
# ...

# %%
df['Cabin'].unique()
# Out:
# array(['B96', 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %% [markdown]
# # 8. Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
lenc=LabelEncoder()

# %%
a = ['Pclass','Sex','Cabin','Ticket','Embarked']
a
# Out:
# ['Pclass', 'Sex', 'Cabin', 'Ticket', 'Embarked']

# %%
df[a] = df[a].apply(lenc.fit_transform)
df[a]
# Out:
#      Pclass  Sex  Cabin  Ticket  Embarked
# 0         2    1     47     523         2
# 1         0    0     82     596         0
# 2         2    0     47     669         2
# 3         0    0     56      49         2
# 4         2    1     47     472         2
# ..      ...  ...    ...     ...       ...
# 886       1    1     47     101         2
# 887       0    0     30      14         2
# 888       2    0     47     675         2
# 889       0    1     61       8         0
# 890       2    1     47     466         1
#
# [891 rows x 5 columns]

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Sex       Age     SibSp  \
# PassengerId     1.000000 -0.005007 -0.035144  0.042939  0.046141 -0.041998
# Survived       -0.005007  1.000000 -0.338481 -0.543351 -0.025726  0.136609
# Pclass         -0.035144 -0.338481  1.000000  0.131900 -0.274381 -0.095322
# Sex             0.042939 -0.543351  0.131900  1.000000  0.057265 -0.186191
# Age             0.046141 -0.025726 -0.274381  0.057265  1.000000 -0.027024
# SibSp          -0.041998  0.136609 -0.095322 -0.186191 -0.027024  1.000000
# Parch           0.005167  0.147408 -0.027526 -0.247523 -0.188854  0.324174
# Ticket         -0.056554 -0.164549  0.319869  0.059372 -0.075055 -0.010499
# Fare            0.003285  0.283273 -0.640577 -0.186195  0.115861  0.350696
# Cabin          -0.018030  0.177538 -0.253872 -0.103276  0.114379  0.085975
# Embarked        0.013128 -0.167675  0.162098  0.108262 -0.012628 -0.041313
#
#                 Parch    Ticket      Fare     Cabin  Embarked
# ...

# %%
df.drop('Name',axis=1,inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  Sex       Age     SibSp     Parch  Ticket  \
# 0              1 -0.789272       2    1 -0.708584  1.302222 -0.560499     523
# 1              2  1.266990       0    0  0.924948  1.302222 -0.560499     596
# 2              3  1.266990       2    0 -0.300201 -0.625340 -0.560499     669
# 3              4  1.266990       0    0  0.618661  1.302222 -0.560499      49
# 4              5 -0.789272       2    1  0.618661 -0.625340 -0.560499     472
# ..           ...       ...     ...  ...       ...       ...       ...     ...
# 886          887 -0.789272       1    1 -0.198105 -0.625340 -0.560499     101
# 887          888  1.266990       0    0 -1.014871 -0.625340 -0.560499      14
# 888          889 -0.789272       2    0  0.077463  1.302222  1.784124     675
# 889          890  1.266990       0    1 -0.300201 -0.625340 -0.560499       8
# 890          891 -0.789272       2    1  0.312373 -0.625340 -0.560499     466
#
#          Fare  Cabin  Embarked
# ...

# %%
sns.heatmap(df.corr(),cmap="rocket",annot=True,annot_kws={'size':5})
plt.show()

# %% [markdown]
# # MODELLING

# %% [markdown]
# # 1. Logistics Modelling

# %%
x = df.drop('Survived','PassengerId',axis=1)
y = df['Survived']
x
# Out:
# C:\Users\JOS\AppData\Local\Temp\ipykernel_948\202970410.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x = df.drop('Survived','PassengerId',axis=1)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_948\202970410.py in <module>
# ----> 1 x = df.drop('Survived','PassengerId',axis=1)
#       2 y = df['Survived']
#       3 x
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: drop() got multiple values for argument 'axis'

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=42)

# %%
x_test.shape
# Out:
# (179, 10)

# %%
from sklearn.linear_model import LogisticRegression
logr=LogisticRegression()
logr.fit(x_train,y_train)
log_pred=logr.predict(x_test)
log_pred
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_948\2758418351.py in <module>
#       1 from sklearn.linear_model import LogisticRegression
#       2 logr=LogisticRegression()
# ----> 3 logr.fit(x_train,y_train)
#       4 log_pred=logr.predict(x_test)
#       5 log_pred
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1514             accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1515         )
# -> 1516         check_classification_targets(y)
#    1517         self.classes_ = np.unique(y)
#    1518
#
# ~\anaconda3\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     195         "multilabel-sequences",
#     196     ]:
# --> 197         raise ValueError("Unknown label type: %r" % y_type)
#     198
#     199
#
# ...
