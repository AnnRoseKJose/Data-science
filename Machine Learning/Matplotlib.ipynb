# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
plt.subplot(221)
plt.plot([1,2,3,4],[1,4,9,16])
plt.subplot(222)
plt.plot([1,2,3,4],[2,4,6,8])
plt.title('Sq-No. Graph')
plt.xlabel('Numbers')
plt.ylabel('Squares')
plt.show()

# %%
im
