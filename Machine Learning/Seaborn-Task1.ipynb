# %%
import seaborn as sns
import pandas as pd
df=pd.read_csv("Dataset_w6.csv")
df
# Out:
#                  country          Region  Surface area (km2)  \
# 0            Afghanistan    SouthernAsia            652864.0
# 1                Albania  SouthernEurope             28748.0
# 2                Algeria  NorthernAfrica           2381741.0
# 3                 Angola    MiddleAfrica           1246700.0
# 4    Antigua and Barbuda       Caribbean               442.0
# ..                   ...             ...                 ...
# 994                  NaN             NaN                 NaN
# 995                  NaN             NaN                 NaN
# 996                  NaN             NaN                 NaN
# 997                  NaN             NaN                 NaN
# 998                  NaN             NaN                 NaN
#
#      Population in thousands (2017)  GDP per capita (current US$)  \
# 0                           35530.0                         623.2
# 1                            2930.0                        3984.2
# ...

# %% [markdown]
# # a) Find out the number of countries in each Region

# %%
a=df.groupby('Region')[['country']].count()
a.reset_index(inplace=True)
a
# Out:
#                Region  country
# 0           Caribbean       16
# 1      CentralAmerica        8
# 2         CentralAsia        5
# 3       EasternAfrica       17
# 4         EasternAsia        7
# 5       EasternEurope       10
# 6           Melanesia        5
# 7          Micronesia        4
# 8        MiddleAfrica        9
# 9      NorthernAfrica        5
# 10    NorthernAmerica        4
# 11     NorthernEurope       10
# 12            Oceania        2
# 13          Polynesia        5
# 14  South-easternAsia       11
# 15       SouthAmerica       12
# 16     SouthernAfrica        5
# 17       SouthernAsia        9
# 18     SouthernEurope       12
# 19      WesternAfrica       15
# 20        WesternAsia       18
# 21      WesternEurope        7

# %%
import matplotlib.pyplot as plt
sns.countplot(df['Region'])
#sns.set_xticklabels(rotation=90)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\JOS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
