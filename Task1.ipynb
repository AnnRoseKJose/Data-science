# %%
import pandas as pd
df=pd.read_csv("StudentsPerformance.csv")

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C            some high school  free/reduced
# 1  female        group B                 high school  free/reduced
# 2  female        group B            some high school  free/reduced
# 3  female        group B                some college      standard
# 4  female        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none           0             17             10
# 1                    none           8             24             23
# 2                    none          18             32             28
# 3                    none          11             38             32
# 4                    none          22             39             33

# %%
df.tail()
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 995   male        group E                some college      standard
# 996   male        group A                some college      standard
# 997   male        group D                some college      standard
# 998   male        group E          associate's degree  free/reduced
# 999   male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 995               completed          99             87             81
# 996               completed         100             96             86
# 997               completed         100             97             99
# 998               completed         100            100             93
# 999               completed         100            100            100

# %%
df.loc[4:78,'gender':'math score']
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 4   female        group C                some college  free/reduced
# 5   female        group B                 high school  free/reduced
# 6   female        group B            some high school  free/reduced
# 7   female        group D          associate's degree  free/reduced
# 8   female        group D            some high school  free/reduced
# ..     ...            ...                         ...           ...
# 74  female        group C            some high school  free/reduced
# 75  female        group C            some high school  free/reduced
# 76  female        group D            some high school      standard
# 77  female        group D            some high school  free/reduced
# 78  female        group A                some college  free/reduced
#
#    test preparation course  math score
# 4                     none          22
# 5                completed          23
# ...

# %%
df.iloc[4:78,3:7]
# Out:
#            lunch test preparation course  math score  reading score
# 4   free/reduced                    none          22             39
# 5   free/reduced               completed          23             44
# 6   free/reduced                    none          24             38
# 7   free/reduced                    none          26             31
# 8   free/reduced                    none          19             34
# ..           ...                     ...         ...            ...
# 73      standard                    none          48             62
# 74  free/reduced                    none          48             58
# 75  free/reduced                    none          48             56
# 76      standard                    none          48             58
# 77  free/reduced                    none          48             54
#
# [74 rows x 4 columns]

# %% [markdown]
# ## To find the number of male and female participated in test

# %%
df['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
df.count()
# Out:
# gender                         1000
# race/ethnicity                 1000
# parental level of education    1000
# lunch                          1000
# test preparation course        1000
# math score                     1000
# reading score                  1000
# writing score                  1000
# dtype: int64

# %%
df['race/ethnicity'].value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %% [markdown]
# ## Student parental education

# %%
df['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
df['total score']=df['math score']+df['reading score']+df['writing score']
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df.groupby('parental level of education')[['total score']].mean()
# Out:
#                              total score
# parental level of education
# associate's degree            209.027027
# bachelor's degree             215.669492
# high school                   188.826531
# master's degree               221.881356
# some college                  205.730088
# some high school              194.782123

# %%
 df.groupby(['parental level of education','test preparation course'])[['reading score', 'math score', 'writing score']].mean()
# Out:
#                                                      reading score  \
# parental level of education test preparation course
# associate's degree          completed                    76.414634
#                             none                         67.857143
# bachelor's degree           completed                    76.739130
#                             none                         70.611111
# high school                 completed                    68.196429
#                             none                         63.164286
# master's degree             completed                    79.950000
#                             none                         73.897436
# some college                completed                    76.506494
#                             none                         65.979866
# some high school            completed                    70.779221
#                             none                         63.725490
#
# ...

# %% [markdown]
# ## Who scores the most on average for math, reading and writing based on gender

# %%
df['average score']=(df['math score']+df['reading score']+df['writing score'])/3

df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df.groupby('gender')[['average score']].mean()
# Out:
#         average score
# gender
# female      69.478121
# male        65.937759

# %%
df.groupby('gender')[['total score']].mean()
# Out:
#         total score
# gender
# female   208.434363
# male     197.813278

# %% [markdown]
# ## Who scores the most on average for math, reading and writing based on Test preparation course

# %%
df.groupby('gender')[['test preparation course']].value_counts()
# Out:
# gender  test preparation course
# female  none                       334
#         completed                  184
# male    none                       308
#         completed                  174
# dtype: int64

# %% [markdown]
# ## What do you think about the scoring variation for math, reading and writing based on Gender

# %%
df.groupby('gender')[[ 'math score','reading score', 'writing score']].mean().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='gender'>

# %% [markdown]
# ## What do you think about the scoring variation for math, reading and writing based on Test preparation course

# %%
df.groupby('test preparation course')[[ 'math score','reading score', 'writing score']].mean()
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                  69.96648      74.175978      74.684358
# none                       63.78972      66.417445      64.457944

# %%
df.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df.groupby('test preparation course')[[ 'math score','reading score', 'writing score']].mean().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='test preparation course'>

# %% [markdown]
#  ## The management needs your help to give bonus points to the top 25% of students based on their maths score, so how will you help the management to achieve this.

# %%
df.describe()
# Out:
#         math score  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     66.001000      69.195000      68.119000
# std      15.569567      14.706436      15.226381
# min       0.000000      17.000000      10.000000
# 25%      57.000000      59.000000      58.000000
# 50%      66.000000      70.000000      69.000000
# 75%      77.000000      79.250000      79.000000
# max     100.000000     100.000000     100.000000

# %%
a=df.sort_values(by="math score", axis=0, ascending=False)
a
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999    male        group E           bachelor's degree      standard
# 996    male        group A                some college      standard
# 515  female        group E                some college      standard
# 517  female        group E          associate's degree      standard
# 516  female        group E           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 2    female        group B            some high school  free/reduced
# 51   female        group C            some high school  free/reduced
# 3    female        group B                some college      standard
# 1    female        group B                 high school  free/reduced
# 0    female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
a.quantile(0.75,axis=0)
# Out:
# math score       77.00
# reading score    79.25
# writing score    79.00
# Name: 0.75, dtype: float64

# %%
df['math score']>77
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995     True
# 996     True
# 997     True
# 998     True
# 999     True
# Name: math score, Length: 1000, dtype: bool

# %%
c=df[df['math score']>77]
c
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 430  female        group A                some college      standard
# 431  female        group B           bachelor's degree  free/reduced
# 432  female        group D           bachelor's degree      standard
# 433  female        group D                 high school      standard
# 434  female        group D           bachelor's degree  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.describe()
# Out:
#         math score  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     66.001000      69.195000      68.119000
# std      15.569567      14.706436      15.226381
# min       0.000000      17.000000      10.000000
# 25%      57.000000      59.000000      58.000000
# 50%      66.000000      70.000000      69.000000
# 75%      77.000000      79.250000      79.000000
# max     100.000000     100.000000     100.000000

# %%
if df[df['math score']>77]:
    df['bonus score']=df['math score']+df['reading score']+df['writing score']+10
else:
    df['bonus score']=df['math score']+df['reading score']+df['writing score']
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6616\4164999703.py in <module>
# ----> 1 if df[df['math score']>77]:
#       2     df['bonus score']=df['math score']+df['reading score']+df['writing score']+10
#       3 else:
#       4     df['bonus score']=df['math score']+df['reading score']+df['writing score']
#       5 df
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1525     @final
#    1526     def __nonzero__(self):
# -> 1527         raise ValueError(
#    1528             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df.loc[430:1000]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 430  female        group A                some college      standard
# 431  female        group B           bachelor's degree  free/reduced
# 432  female        group D           bachelor's degree      standard
# 433  female        group D                 high school      standard
# 434  female        group D           bachelor's degree  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
c['bonus score']=c['math score']+c['reading score']+c['writing score']+10
c
# Out:
# C:\Users\JOS\AppData\Local\Temp\ipykernel_7956\3787250516.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c['bonus score']=c['math score']+c['reading score']+c['writing score']+10
#      gender race/ethnicity parental level of education         lunch  \
# 430  female        group A                some college      standard
# 431  female        group B           bachelor's degree  free/reduced
# 432  female        group D           bachelor's degree      standard
# 433  female        group D                 high school      standard
# 434  female        group D           bachelor's degree  free/reduced
# ..      ...            ...                         ...           ...
# ...

# %%
import numpy as np

# %%
df['bonus']= np.where(df['math score']>77,df['math score']+df['reading score']+df['writing score']+15,df['math score']+df['reading score']+df['writing score'])

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
def fdfd(a):
    gvhhjl
    return 

df= df.apply( lambda a : fdfd(a))
